# %%
import pandas as pd

df = pd.read_parquet("../data/silver/exchange_rates/usd_brl.parquet")

df.head()
# Out:
#   code codein                             name    high      low     bid  \
# 0  USD    BRL  Dólar Americano/Real Brasileiro  5.0364  4.99296  5.0101
#
#       ask   timestamp
# 0  5.0131  1779748776
